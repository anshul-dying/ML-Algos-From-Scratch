# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from linearReg import LinearRegression

# %%
df = pd.read_csv('salary_data.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %% [markdown]
# # Linear Regression

# %%
reg = LinearRegression(0.01, 10000)
X = df[['YearsExperience']]
y = df['Salary']

reg.fit(X.values, y.values)
# Out:
# array([25792.20018579,  9449.96232336])

# %%
plt.scatter(X, y)
x = range(1, 12)
eqn = reg.weights[0] + reg.weights[1] * x
plt.plot(eqn, c='red')

# %% [markdown]
# # Ridge Regression

# %%
from linearReg import RidgeRegression

# %%
ridge = RidgeRegression(iterations=10000)
ridge.fit(X.values, y.values)
# Out:
# array([26218.5199076 ,  9369.72649121])

# %%
plt.scatter(X, y)
x = range(1, 12)
eqn = ridge.weights[0] + ridge.weights[1] * x
plt.plot(eqn, c='red')

# %%
from sklearn.metrics import r2_score

y_pred_lin = reg.predict(X.values)
y_pred_rid = ridge.predict(X.values)

print(f"R2 Score of Linear Regression: {r2_score(y, y_pred_lin):.4f}")
print(f"R2 Score of Ridge Regression: {r2_score(y, y_pred_rid):.4f}")
# Out:
# R2 Score of Linear Regression: 0.9570
# R2 Score of Ridge Regression: 0.9569
