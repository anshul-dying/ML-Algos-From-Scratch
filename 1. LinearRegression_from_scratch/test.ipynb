# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from linearReg import LinearRegression

# %%
df = pd.read_csv('salary_data.csv')
df.head()
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
reg = LinearRegression(0.001, 1000)
X = df[['YearsExperience']]
y = df['Salary']

reg.fit(X.values, y.values)
# Out:
# array([ 6482.30302252, 12314.876697  ])

# %%
plt.scatter(X, y)
x = range(1, 12)
eqn = reg.weights[0] + reg.weights[1] * x
plt.plot(eqn, c='red')

# %%
from linearReg import RidgeRegression

# %%
ridge = RidgeRegression()
ridge.fit(X.values, y.values)
# Out:
# array([23385.3626085 ,  9788.50924903])

# %%
plt.scatter(X, y)
x = range(1, 12)
eqn = ridge.weights[0] + ridge.weights[1] * x
plt.plot(eqn, c='red')
